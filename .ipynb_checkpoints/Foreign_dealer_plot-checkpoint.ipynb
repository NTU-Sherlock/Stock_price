# %%
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockTotalInstitutionalInvestors",
    "start_date": "2020-05-18",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
df = pd.DataFrame(data['data'])
print(df.head())
# Out:
#            buy        date                 name         sell
# 0      2909100  2020-05-18  Foreign_Dealer_Self      6221900
# 1  59041684613  2020-05-18                total  75986271228
# 2   2397261070  2020-05-18          Dealer_self   2366355498
# 3   4780109334  2020-05-18       Dealer_Hedging   5042725265
# 4  48897993579  2020-05-18     Foreign_Investor  64798454327

# %%
df1 = df[df['name']=='Foreign_Investor']

# %%
df
# Out:
#                buy        date                 name          sell
# 0          2909100  2020-05-18  Foreign_Dealer_Self       6221900
# 1      59041684613  2020-05-18                total   75986271228
# 2       2397261070  2020-05-18          Dealer_self    2366355498
# 3       4780109334  2020-05-18       Dealer_Hedging    5042725265
# 4      48897993579  2020-05-18     Foreign_Investor   64798454327
# ...            ...         ...                  ...           ...
# 1465    5514326027  2021-05-18          Dealer_self    3529948768
# 1466   10160696342  2021-05-18       Dealer_Hedging    5734240023
# 1467    3588549320  2021-05-18     Investment_Trust    2315708650
# 1468  131492061015  2021-05-18     Foreign_Investor  109357752546
# 1469  150755632704  2021-05-18                total  120937649987
#
# [1470 rows x 4 columns]

# %%
df1
# Out:
#                buy        date              name          sell
# 4      48897993579  2020-05-18  Foreign_Investor   64798454327
# 10     58609712845  2020-05-19  Foreign_Investor   53960035648
# 13     46532822396  2020-05-20  Foreign_Investor   42143417391
# 23     42073642951  2020-05-21  Foreign_Investor   41094682114
# 28     29571380095  2020-05-22  Foreign_Investor   58656962130
# ...            ...         ...               ...           ...
# 1444  215804742128  2021-05-12  Foreign_Investor  227991993137
# 1447  147674647100  2021-05-13  Foreign_Investor  170344551548
# 1456  120384188923  2021-05-14  Foreign_Investor  134040078728
# 1459  153805594777  2021-05-17  Foreign_Investor  120388557736
# 1468  131492061015  2021-05-18  Foreign_Investor  109357752546
#
# [245 rows x 4 columns]

# %%
df1.set_index('date').plot()

# %%
fig = px.line(df, x="date", y='sell',
              hover_data={"date": "|%B %d, %Y"},
              title='custom tick labels')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-82e7cd13b07b> in <module>
#       1 fig = px.line(df, x="date", y='sell',
#       2               hover_data={"date": "|%B %d, %Y"},
# ----> 3               title='custom tick labels')
#       4
#       5 fig.show()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     212     a polyline mark in 2D space.
#     213     """
# ...

# %%
df['surplus'] = df['buy'] - df['sell']

# %%
fig = px.bar(df, x='date', y="surplus")
fig.show()
# Out:
# <div>
#
#
#             <div id="4279d76c-7cdc-4d1b-9db7-d21aab3435e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4279d76c-7cdc-4d1b-9db7-d21aab3435e1")) {
#                     Plotly.newPlot(
#                         '4279d76c-7cdc-4d1b-9db7-d21aab3435e1',
# ...

# %%
fig = px.bar(df, x='date', y="sell")
fig.show()
# Out:
# <div>
#
#
#             <div id="3dca593b-2262-439f-a67e-9b248949de69" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3dca593b-2262-439f-a67e-9b248949de69")) {
#                     Plotly.newPlot(
#                         '3dca593b-2262-439f-a67e-9b248949de69',
# ...

# %%
fig = px.bar(df, x='date', y="buy")
fig.show()
# Out:
# <div>
#
#
#             <div id="7d150a6d-423c-476c-8f7f-bb7a359aad70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7d150a6d-423c-476c-8f7f-bb7a359aad70")) {
#                     Plotly.newPlot(
#                         '7d150a6d-423c-476c-8f7f-bb7a359aad70',
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig)
])

app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on

# %%
import plotly.express as px
fig.write_html("buy.html")

# %%
# !pip3 install dash
# Out:
# ...
#      |████████████████████████████████| 81kB 1.3MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 102kB 3.1MB/s ta 0:00:011
# ...
#      |████████████████████████████████| 1.0MB 7.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.5MB 140kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 92kB 14.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8MB 13.9MB/s eta 0:00:01     |████████████████████████████    | 1.6MB 13.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 829kB 15.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 296kB 8.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 102kB 13.0MB/s ta 0:00:01
# ...
#      |████████████████████████████████| 143kB 10.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 430kB 5.8MB/s eta 0:00:01
# ...
# ERROR: pandas-profiling 2.5.0 has requirement jinja2==2.11.1, but you'll have jinja2 3.0.0 which is incompatible.
# ...

# %%
import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc 
import dash_html_components as html

from pandas_datareader import data as web 
from datetime import datetime as dt

# %%
import os
import datetime
import pandas as pd
import plotly.graph_objects as go

# %%
def get_plot(df, symbol = 'Foreign_Investor', value ='sell'):
    
    ## filter specific symbol and calculate the moving average
    df = df.loc[df['name'] == symbol]
    df = df.sort_values('date')
    
    ## create plotly object
    fig = go.Figure(layout = go.Layout(plot_bgcolor = '#EEEEEE'))
    fig.add_trace(go.Scatter(
        x = df["date"], y = df[value],
        name = '%s/%s' %(symbol, value),
        fill = 'tozeroy',
        line_width = 0,
        line_color = 'rgba(72,89,110,1)',
        fillcolor = 'rgba(72,89,110,0.8)',
    ))
    fig.update_layout(
        width = 600, height = 400,
        margin=dict(l = 20, r = 20, t = 20, b = 20),
        legend = dict(
            orientation = "h",
            yanchor = "bottom",
            y = 1.02,
            xanchor = "right",
            x = 1
        )
    )
    
    return fig

# %%
get_plot(df)
# Out:
# <div>
#
#
#             <div id="0d484345-4225-4161-acee-c4b3b266cfef" class="plotly-graph-div" style="height:400px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d484345-4225-4161-acee-c4b3b266cfef")) {
#                     Plotly.newPlot(
#                         '0d484345-4225-4161-acee-c4b3b266cfef',
# ...

# %%
data.name.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Foreign_Dealer_Self
# 1                     total
# 2               Dealer_self
# 3            Dealer_Hedging
# 4          Foreign_Investor
#                ...
# 1465            Dealer_self
# 1466         Dealer_Hedging
# 1467       Investment_Trust
# 1468       Foreign_Investor
# 1469                  total
# Name: name, Length: 1470, dtype: object>

# %%
data
# Out:
#                buy        date                 name          sell
# 0          2909100  2020-05-18  Foreign_Dealer_Self       6221900
# 1      59041684613  2020-05-18                total   75986271228
# 2       2397261070  2020-05-18          Dealer_self    2366355498
# 3       4780109334  2020-05-18       Dealer_Hedging    5042725265
# 4      48897993579  2020-05-18     Foreign_Investor   64798454327
# ...            ...         ...                  ...           ...
# 1465    5514326027  2021-05-18          Dealer_self    3529948768
# 1466   10160696342  2021-05-18       Dealer_Hedging    5734240023
# 1467    3588549320  2021-05-18     Investment_Trust    2315708650
# 1468  131492061015  2021-05-18     Foreign_Investor  109357752546
# 1469  150755632704  2021-05-18                total  120937649987
#
# [1470 rows x 4 columns]

# %%
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockTotalInstitutionalInvestors",
    "start_date": "2020-04-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
# Out:
#            buy        date                 name         sell
# 0       123150  2020-04-01  Foreign_Dealer_Self       266220
# 1   3039112340  2020-04-01     Investment_Trust    853138940
# 2   3681729831  2020-04-01       Dealer_Hedging   5539788946
# 3    789316840  2020-04-01          Dealer_self    912143500
# 4  33759089839  2020-04-01     Foreign_Investor  38466572585

# %%
data[data.date =='2021-05-18']
# Out:
#                buy        date                 name          sell
# 1464      36213460  2021-05-18  Foreign_Dealer_Self      29804940
# 1465    5514326027  2021-05-18          Dealer_self    3529948768
# 1466   10160696342  2021-05-18       Dealer_Hedging    5734240023
# 1467    3588549320  2021-05-18     Investment_Trust    2315708650
# 1468  131492061015  2021-05-18     Foreign_Investor  109357752546
# 1469  150755632704  2021-05-18                total  120937649987

# %%
data.name.value_counts()
# Out:
# Dealer_Hedging         275
# Dealer_self            275
# total                  275
# Investment_Trust       275
# Foreign_Dealer_Self    275
# Foreign_Investor       275
# Name: name, dtype: int64

# %%
from FinMind import Mind

_2330 = Mind.Stock('2330','2019-01-01')
print(_2330.StockPrice)
_2330.FinancialStatements
_2330.ShareHolding
_2330.InstitutionalInvestors
_2330.MarginPurchaseShortSale
_2330.MonthRevenue
_2330.HoldingSharesPer
_2330.BalanceSheet
 
_2330.StockPrice['move_average'] = Mind.MoveAverage(    _2330.StockPrice,days = 5,variable = 'close')
_2330.StockPrice['RSV'] = Mind.RSV(_2330.StockPrice,days = 5)
_2330.StockPrice['BIAS'] = Mind.BIAS(_2330.StockPrice,days = 5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-4880e6e6baa3> in <module>
# ----> 1 from FinMind import Mind
#       2
#       3 _2330 = Mind.Stock('2330','2019-01-01')
#       4 print(_2330.StockPrice)
#       5 _2330.FinancialStatements
#
# ImportError: cannot import name 'Mind' from 'FinMind' (/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/FinMind/__init__.py)

# %%
import pandas as pd
import numpy as np
import FinMind
from ta.momentum import StochasticOscillator
from FinMind.BackTestSystem.BaseClass import Strategy
from FinMind.BackTestSystem import BackTest

obj = BackTest(
stock_id="0056",
start_date="2018-01-01",
end_date="2019-01-01",
trader_fund=500000.0,
fee=0.001425,
)
obj.stock_price
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-abd3148fc8a3> in <module>
#       3 import FinMind
#       4 from ta.momentum import StochasticOscillator
# ----> 5 from FinMind.BackTestSystem.BaseClass import Strategy
#       6 from FinMind.BackTestSystem import BackTest
#       7
#
# ModuleNotFoundError: No module named 'FinMind.BackTestSystem'
